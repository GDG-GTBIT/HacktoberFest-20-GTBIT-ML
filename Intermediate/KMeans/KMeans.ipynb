# %% [markdown]
# # K- Means Clustering

# %% [markdown]
# # PROBLEM STATEMENT: From the given ‘Iris’ dataset, predict the optimum number of clusters

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.cluster import KMeans

# %%
df = pd.read_csv('Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
#creating a histogram for variables
df.hist(figsize = (15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000229182C0B48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000229182FB208>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002291832E3C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002291835FE08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022918395B88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002291974E908>]],
#       dtype=object)

# %%
#to plot pairwise relationship in a dataset
sns.pair_plot(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-787114ccc61c> in <module>
#       1 #to plot pairwise relationship in a dataset
# ----> 2 sns.pair_plot(df)
#
# AttributeError: module 'seaborn' has no attribute 'pair_plot'

# %%
# Finding the optimum number of clusters for k-means classification

x = df.iloc[:,[1,2,3,4]].values

inner = []

for i in range(1, 11)
    kmeans = Kmeans(n_clusters = i, init = 'k-means++', 
                    max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(x)
    inner.append[kmeans.inertia_]
# Out:
#   File "<ipython-input-35-968a4aaa9cf6>", line 7
#     for i in range(1, 11)
#                          ^
# SyntaxError: invalid syntax

# %%
# Plotting the results in a line graph and to observe 'The elbow'
plt.plot(range(1, 11), inner)
plt.title('The elbow curve')
plt.xlabel('Number of clusters')
plt.ylabel('Within cluster sum of squares') 
plt.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-afa6dc7c5f2d> in <module>
#       1 # Plotting the results in a line graph and to observe 'The elbow'
# ----> 2 plt.plot(range(1, 11), inner)
#       3 plt.title('The elbow curve')
#       4 plt.xlabel('Number of clusters')
#       5 plt.ylabel('Within cluster sum of squares')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2794     return gca().plot(
#    2795         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2796         is not None else {}), **kwargs)
#    2797
#    2798
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1663         """
#    1664         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1665         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666         for line in lines:
#    1667             self.add_line(line)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     389             x, y = index_of(tup[-1])
#     390
# --> 391         x, y = self._xy_from_xy(x, y)
#     392
#     393         if self.command == 'plot':
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _xy_from_xy(self, x, y)
#     268         if x.shape[0] != y.shape[0]:
#     269             raise ValueError("x and y must have same first dimension, but "
# --> 270                              "have shapes {} and {}".format(x.shape, y.shape))
#     271         if x.ndim > 2 or y.ndim > 2:
#     272             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (10,) and (0,)

# %%
# Applying kmeans to the dataset and creating the kmeans classifier
kmeans = Kmeans(n_clusters = 3, init = 'k-means++',
                max_iter = 300, n_init = 10, random_state = 0)
y_kmeans = kmeans.fit_predict(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-311e00c2b598> in <module>
#       1 # Applying kmeans to the dataset and creating the kmeans classifier
# ----> 2 kmeans = Kmeans(n_clusters = 3, init = 'k-means++',
#       3                 max_iter = 300, n_init = 10, random_state = 0)
#       4 y_kmeans = kmeans.fit_predict(x)
#
# NameError: name 'Kmeans' is not defined

# %%
# Visualising the clusters on two columns
plt.figure(figsize = [7,7])
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], 
            s = 100, c = 'red', label = 'Iris-setosa')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], 
            s = 100, c = 'blue', label = 'Iris-versicolour')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1],
            s = 100, c = 'green', label = 'Iris-virginica')

# Plotting the centroids of the clusters
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], 
            s = 100, c = 'yellow', label = 'Centroids')

plt.legend(loc = 'upper right')
plt.display()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-c36c3074b134> in <module>
#      13
#      14 plt.legend(loc = 'upper right')
# ---> 15 plt.display()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'display'
